# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movie_df = pd.read_json('movie.json')

# %%
review_df = pd.read_json('review.json')

# %%
movie_df.head()
# Out:
#    id                              title  \
# 0   1                             Planes
# 1   2  Big Mommas: Like Father, Like Son
# 2   3                   Babes in Toyland
# 3   4             Million Dollar Mystery
# 4   5                       Street Kings
#
#                                              summary  \
# 0  Morbi quis tortor id nulla ultrices aliquet. M...
# 1  Cum sociis natoque penatibus et magnis dis par...
# 2  Curabitur convallis. Duis consequat dui nec ni...
# 3  Nam dui. Proin leo odio, porttitor id, consequ...
# 4                     Integer a nibh. In quis justo.
#
#                         genre  attendance        year
# 0  Adventure|Animation|Comedy       49040  2019-05-20
# 1                      Comedy       38346  2011-12-14
# 2    Children|Fantasy|Musical       79006  2003-05-06
# 3                      Comedy       69522  1998-11-19
# 4        Crime|Drama|Thriller       20420  2021-02-22

# %%
review_df.head()
# Out:
#    id  movieId  userId                                            content  \
# 0   1      863     189                        Proin eu mi. Nulla ac enim.
# 1   2      608     217           Mauris ullamcorper purus sit amet nulla.
# 2   3      405       6            Nulla tellus. In sagittis dui vel nisl.
# 3   4      959     238  Morbi sem mauris, laoreet ut, rhoncus aliquet,...
# 4   5      839     122  Ut tellus. Nulla ut erat id mauris vulputate e...
#
#    rating            createdAt            updatedAt
# 0       4  2024-05-17 08:52:36  2024-05-17 08:52:36
# 1       3  2024-05-17 08:52:36  2024-05-17 08:52:36
# 2       2  2024-05-17 08:52:36  2024-05-17 08:52:36
# 3       5  2024-05-17 08:52:36  2024-05-17 08:52:36
# 4       3  2024-05-17 08:52:36  2024-05-17 08:52:36

# %%
movie_df.rename(columns={'id':'movieId'}, inplace=True)

# %%
movie_df.head(2)
# Out:
#    movieId                              title  \
# 0        1                             Planes
# 1        2  Big Mommas: Like Father, Like Son
#
#                                              summary  \
# 0  Morbi quis tortor id nulla ultrices aliquet. M...
# 1  Cum sociis natoque penatibus et magnis dis par...
#
#                         genre  attendance        year
# 0  Adventure|Animation|Comedy       49040  2019-05-20
# 1                      Comedy       38346  2011-12-14

# %%
df = pd.merge(movie_df, review_df, on='movieId', how='left')

# %%
df = df[['movieId', 'title', 'userId', 'rating']]

# %%
df
# Out:
#       movieId                              title  userId  rating
# 0           1                             Planes   286.0     4.0
# 1           2  Big Mommas: Like Father, Like Son   109.0     2.0
# 2           2  Big Mommas: Like Father, Like Son   188.0     3.0
# 3           2  Big Mommas: Like Father, Like Son   243.0     4.0
# 4           3                   Babes in Toyland   107.0     3.0
# ...       ...                                ...     ...     ...
# 1371      997                    Black Hole, The   178.0     3.0
# 1372      997                    Black Hole, The   205.0     1.0
# 1373      998                    Little Fugitive   113.0     2.0
# 1374      999    Monty Python and the Holy Grail   224.0     4.0
# 1375     1000           Loins of Punjab Presents     NaN     NaN
#
# [1376 rows x 4 columns]

# %%
# 각 영화 제목별로, 별점에 대한 기본 통계치를 확인해보자

# %%
df.groupby('movieId')['rating'].describe()
# Out:
#          count      mean       std  min  25%  50%  75%  max
# movieId
# 1          1.0  4.000000       NaN  4.0  4.0  4.0  4.0  4.0
# 2          3.0  3.000000  1.000000  2.0  2.5  3.0  3.5  4.0
# 3          1.0  3.000000       NaN  3.0  3.0  3.0  3.0  3.0
# 4          1.0  3.000000       NaN  3.0  3.0  3.0  3.0  3.0
# 5          0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# ...        ...       ...       ...  ...  ...  ...  ...  ...
# 996        0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 997        3.0  1.666667  1.154701  1.0  1.0  1.0  2.0  3.0
# 998        1.0  2.000000       NaN  2.0  2.0  2.0  2.0  2.0
# 999        1.0  4.000000       NaN  4.0  4.0  4.0  4.0  4.0
# 1000       0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
#
# [1000 rows x 8 columns]

# %%
df
# Out:
#       movieId                              title  userId  rating
# 0           1                             Planes   286.0     4.0
# 1           2  Big Mommas: Like Father, Like Son   109.0     2.0
# 2           2  Big Mommas: Like Father, Like Son   188.0     3.0
# 3           2  Big Mommas: Like Father, Like Son   243.0     4.0
# 4           3                   Babes in Toyland   107.0     3.0
# ...       ...                                ...     ...     ...
# 1371      997                    Black Hole, The   178.0     3.0
# 1372      997                    Black Hole, The   205.0     1.0
# 1373      998                    Little Fugitive   113.0     2.0
# 1374      999    Monty Python and the Holy Grail   224.0     4.0
# 1375     1000           Loins of Punjab Presents     NaN     NaN
#
# [1376 rows x 4 columns]

# %%
df.corr(numeric_only=True)
# Out:
#           movieId    userId    rating
# movieId  1.000000 -0.027543  0.031241
# userId  -0.027543  1.000000 -0.023909
# rating   0.031241 -0.023909  1.000000

# %%
# 영화 제목이 컬럼부분에 위치를 해야 상관계수를 뽑을 수 있다.
# 영화제목은 컬럼으로, 유저아이디는 인덱스로, 유저가 준 별점은 데이터로
# 들어가도록 데이터프레임을 가공해야 한다.

# %%
corr_movie = df.pivot_table(index='userId', columns='title', values='rating', aggfunc='mean')

# %%
corr_movie
# Out:
# title   12 Storeys (Shier lou)  13 Ghosts  21 Hours at Munich  \
# userId
# 1.0                        NaN        NaN                 NaN
# 2.0                        NaN        NaN                 NaN
# 3.0                        NaN        NaN                 NaN
# 4.0                        NaN        NaN                 NaN
# 5.0                        NaN        NaN                 NaN
# ...                        ...        ...                 ...
# 297.0                      NaN        NaN                 NaN
# 298.0                      NaN        NaN                 NaN
# 299.0                      NaN        NaN                 NaN
# 300.0                      NaN        NaN                 NaN
# 301.0                      NaN        NaN                 NaN
#
# title   30 Days of Night  33 Postcards  \
# userId
# 1.0                  NaN           NaN
# 2.0                  NaN           NaN
# 3.0                  NaN           NaN
# 4.0                  NaN           NaN
# 5.0                  NaN           NaN
# ...                  ...           ...
# 297.0                NaN           NaN
# 298.0                NaN           NaN
# 299.0                NaN           NaN
# 300.0                NaN           NaN
# 301.0                NaN           NaN
#
# title   4 Months, 3 Weeks and 2 Days (4 luni, 3 saptamâni si 2 zile)  \
# userId
# 1.0                                                   NaN
# 2.0                                                   NaN
# 3.0                                                   NaN
# 4.0                                                   NaN
# 5.0                                                   3.0
# ...                                                   ...
# 297.0                                                 NaN
# 298.0                                                 NaN
# 299.0                                                 NaN
# 300.0                                                 NaN
# 301.0                                                 NaN
#
# title   71 Fragments of a Chronology of Chance (71 Fragmente einer Chronologie des Zufalls)  \
# userId
# 1.0                                                   NaN
# 2.0                                                   NaN
# 3.0                                                   NaN
# 4.0                                                   NaN
# 5.0                                                   NaN
# ...                                                   ...
# 297.0                                                 NaN
# 298.0                                                 NaN
# 299.0                                                 NaN
# 300.0                                                 NaN
# 301.0                                                 NaN
#
# title   7500  8MM  A Magnificent Haunting  ...  Woodstock  Wrongfully Accused  \
# userId                                     ...
# 1.0      NaN  NaN                     NaN  ...        NaN                 NaN
# 2.0      NaN  NaN                     NaN  ...        NaN                 NaN
# 3.0      NaN  NaN                     NaN  ...        NaN                 NaN
# 4.0      NaN  NaN                     NaN  ...        NaN                 NaN
# 5.0      NaN  NaN                     NaN  ...        NaN                 NaN
# ...      ...  ...                     ...  ...        ...                 ...
# 297.0    NaN  NaN                     NaN  ...        NaN                 NaN
# 298.0    NaN  NaN                     NaN  ...        NaN                 NaN
# 299.0    NaN  NaN                     NaN  ...        NaN                 NaN
# 300.0    NaN  NaN                     NaN  ...        NaN                 NaN
# 301.0    NaN  NaN                     NaN  ...        NaN                 NaN
#
# title   Xtro 2: The Second Encounter  Yanks  \
# userId
# 1.0                              NaN    NaN
# 2.0                              NaN    NaN
# 3.0                              NaN    NaN
# 4.0                              NaN    NaN
# 5.0                              NaN    NaN
# ...                              ...    ...
# 297.0                            NaN    NaN
# 298.0                            NaN    NaN
# 299.0                            NaN    NaN
# 300.0                            NaN    NaN
# 301.0                            NaN    NaN
#
# title   Year and a Half in the Life of Metallica, A  You've Got Mail  \
# userId
# 1.0                                             NaN              NaN
# 2.0                                             NaN              NaN
# 3.0                                             NaN              NaN
# 4.0                                             NaN              NaN
# 5.0                                             NaN              NaN
# ...                                             ...              ...
# 297.0                                           NaN              NaN
# 298.0                                           NaN              NaN
# 299.0                                           NaN              NaN
# 300.0                                           NaN              NaN
# 301.0                                           NaN              NaN
#
# title   Young Adult  Young Bess  Young Black Stallion, The  \
# userId
# 1.0             NaN         NaN                        NaN
# 2.0             NaN         NaN                        NaN
# 3.0             NaN         NaN                        NaN
# 4.0             NaN         NaN                        NaN
# 5.0             NaN         NaN                        NaN
# ...             ...         ...                        ...
# 297.0           NaN         NaN                        NaN
# 298.0           NaN         NaN                        NaN
# 299.0           NaN         NaN                        NaN
# 300.0           NaN         NaN                        NaN
# 301.0           NaN         NaN                        NaN
#
# title   Zombies of the Stratosphere
# userId
# 1.0                             NaN
# 2.0                             NaN
# 3.0                             NaN
# 4.0                             NaN
# 5.0                             NaN
# ...                             ...
# 297.0                           NaN
# 298.0                           NaN
# 299.0                           NaN
# 300.0                           NaN
# 301.0                           NaN
#
# [295 rows x 615 columns]

# %%
corr_movie = corr_movie.corr(min_periods=1)

# %%
corr_movie['13 Ghosts'].dropna()
# Out:
# Series([], Name: 13 Ghosts, dtype: float64)

# %%
# 개인 맞춤형 영화 추천을 해야 하므로,
# 로그인 한 사람의 리뷰정보를 기반으로, 추천을 해줘야 한다.

# %%
my_review_df = review_df.loc[ review_df['userId'] == 1 , ['movieId','rating'] ]

# %%
my_review_df = pd.merge(my_review_df, movie_df, on='movieId')

# %%
my_review_df = my_review_df[['title', 'rating']]

# %%
my_review_df
# Out:
#                                          title  rating
# 0         Silver Stallion (Silver Brumpy, The)       4
# 1                             There Be Dragons       3
# 2                                Hireling, The       3
# 3  I Have Found It (Kandukondain Kandukondain)       3

# %%
title = my_review_df['title'][0]

# %%
title
# Out:
# 'Silver Stallion (Silver Brumpy, The)'

# %%
corr_movie[title].dropna()
# Out:
# Series([], Name: Silver Stallion (Silver Brumpy, The), dtype: float64)

# %%
movie_df
# Out:
#      movieId                              title  \
# 0          1                             Planes
# 1          2  Big Mommas: Like Father, Like Son
# 2          3                   Babes in Toyland
# 3          4             Million Dollar Mystery
# 4          5                       Street Kings
# ..       ...                                ...
# 995      996               Journey for Margaret
# 996      997                    Black Hole, The
# 997      998                    Little Fugitive
# 998      999    Monty Python and the Holy Grail
# 999     1000           Loins of Punjab Presents
#
#                                                summary  \
# 0    Morbi quis tortor id nulla ultrices aliquet. M...
# 1    Cum sociis natoque penatibus et magnis dis par...
# 2    Curabitur convallis. Duis consequat dui nec ni...
# 3    Nam dui. Proin leo odio, porttitor id, consequ...
# 4                       Integer a nibh. In quis justo.
# ..                                                 ...
# 995  Cras pellentesque volutpat dui. Maecenas trist...
# 996  Morbi vestibulum, velit id pretium iaculis, di...
# 997  Vivamus vel nulla eget eros elementum pellente...
# 998  Lorem ipsum dolor sit amet, consectetuer adipi...
# 999  Vivamus vel nulla eget eros elementum pellente...
#
#                           genre  attendance        year
# 0    Adventure|Animation|Comedy       49040  2019-05-20
# 1                        Comedy       38346  2011-12-14
# 2      Children|Fantasy|Musical       79006  2003-05-06
# 3                        Comedy       69522  1998-11-19
# 4          Crime|Drama|Thriller       20420  2021-02-22
# ..                          ...         ...         ...
# 995                   Drama|War       76877  1991-08-30
# 996             Children|Sci-Fi       67715  2005-02-10
# 997                       Drama       69195  2002-04-06
# 998    Adventure|Comedy|Fantasy       52119  2007-02-10
# 999                      Comedy       65535  1994-06-16
#
# [1000 rows x 6 columns]

# %%
movie_df = pd.read_csv('Movie_Id_Titles.csv')

# %%
review_df = pd.read_csv('user_rating.csv')

# %%
df = pd.merge(movie_df, review_df, on = 'item_id', how='left')

# %%
df = df.pivot_table(index='user_id', columns='title', values='rating')

# %%
corr_movie = df.corr(min_periods= 50)

# %%
my_review = review_df.loc[  review_df['user_id'] == 0 , ]

# %%
my_review = pd.merge(my_review, movie_df, on='item_id')[ ['title','rating'] ]

# %%
title = my_review['title'][0]

# %%
my_review
# Out:
#                              title  rating
# 0                 Star Wars (1977)       5
# 1  Empire Strikes Back, The (1980)       5
# 2        Gone with the Wind (1939)       1

# %%
recom_movie = corr_movie[title].dropna().sort_values(ascending=False).to_frame()

# %%
recom_movie.columns = ['correlation']

# %%
recom_movie['weight'] = recom_movie['correlation'] * my_review['rating'][0]

# %%
recom_movie
# Out:
#                                                     correlation    weight
# title
# Star Wars (1977)                                       1.000000  5.000000
# Empire Strikes Back, The (1980)                        0.748353  3.741763
# Return of the Jedi (1983)                              0.672556  3.362779
# Raiders of the Lost Ark (1981)                         0.536117  2.680586
# Austin Powers: International Man of Mystery (1997)     0.377433  1.887164
# ...                                                         ...       ...
# Evil Dead II (1987)                                   -0.190719 -0.953597
# First Wives Club, The (1996)                          -0.194496 -0.972480
# Rosencrantz and Guildenstern Are Dead (1990)          -0.197935 -0.989676
# Jack (1996)                                           -0.217553 -1.087764
# Walk in the Clouds, A (1995)                          -0.257007 -1.285037
#
# [534 rows x 2 columns]

# %%
my_review
# Out:
#                              title  rating
# 0                 Star Wars (1977)       5
# 1  Empire Strikes Back, The (1980)       5
# 2        Gone with the Wind (1939)       1

# %%
# 비어있는 빈 데이터프레임을 만들고,
# 내가 본 영화의 가중치까지 계산해서, 추천영화를 뽑고
# 이 추천영화들을, 위의 빈 데이터프레임에 추가하면 된다.
# 모두 추가한 후에, 정렬한 후, 중복영화 제거하고, 이미본 영화 제거하면 된다.

# %%
movie_list = pd.DataFrame()

# %%
for  i  in np.arange( my_review.shape[0] ) :
  title = my_review['title'][i]
  recom_movie = corr_movie[title].dropna().sort_values(ascending=False).to_frame()
  recom_movie.columns = ['correlation']
  recom_movie['weight'] = recom_movie['correlation'] * my_review['rating'][i]
  movie_list = pd.concat([movie_list, recom_movie])

# %%
# weight 컬럼으로 정렬
movie_list.sort_values(by='weight', ascending=False, inplace=True)

# %%
my_review
# Out:
#                              title  rating
# 0                 Star Wars (1977)       5
# 1  Empire Strikes Back, The (1980)       5
# 2        Gone with the Wind (1939)       1

# %%
# 내가 이미 본 영화는 추천에서 제외한다.
for title in my_review['title'] :
  if title in movie_list.index :
    movie_list.drop(title, axis = 0, inplace=True)

# %%
# 중복된 영화는, 웨이트의 최대값으로 계산해서, 중복제거한다.
movie_list = movie_list.groupby('title')['weight'].max().sort_values(ascending=False).head(5)

# %%
movie_list
# Out:
# title
# Return of the Jedi (1983)         3.606146
# Raiders of the Lost Ark (1981)    2.693297
# Philadelphia Story, The (1940)    2.410756
# Frighteners, The (1996)           2.213803
# Con Air (1997)                    1.996002
# Name: weight, dtype: float64

# %%
movie_list = movie_list.to_frame()

# %%
movie_list
# Out:
#                                   weight
# title
# Return of the Jedi (1983)       3.606146
# Raiders of the Lost Ark (1981)  2.693297
# Philadelphia Story, The (1940)  2.410756
# Frighteners, The (1996)         2.213803
# Con Air (1997)                  1.996002

# %%
movie_list.reset_index(inplace=True)

# %%
movie_list
# Out:
#                             title    weight
# 0       Return of the Jedi (1983)  3.606146
# 1  Raiders of the Lost Ark (1981)  2.693297
# 2  Philadelphia Story, The (1940)  2.410756
# 3         Frighteners, The (1996)  2.213803
# 4                  Con Air (1997)  1.996002

# %%
movie_list.to_dict('records')
# Out:
# [{'title': 'Return of the Jedi (1983)', 'weight': 3.6061458421360553},
#  {'title': 'Raiders of the Lost Ark (1981)', 'weight': 2.6932973548246797},
#  {'title': 'Philadelphia Story, The (1940)', 'weight': 2.410755839365285},
#  {'title': 'Frighteners, The (1996)', 'weight': 2.213802950575534},
#  {'title': 'Con Air (1997)', 'weight': 1.9960024295672594}]
